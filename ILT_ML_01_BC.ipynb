# %% [markdown]
# <a href="https://colab.research.google.com/github/irfansubakti/demo-ilt-2-ml/blob/main/ILT_ML_01_BC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !python --version
# Out:
# Python 3.10.12

# %%
print("Bangkit 2023")
# Out:
# Bangkit 2023

# %%
length = 10
width = 2
name = "Saturnus"

# %%
def = "Function"
class = "Class"
# Out:
#   File "<ipython-input-4-7aff832ba152>", line 1
#     def = "Function"
#         ^
# SyntaxError: invalid syntax

# %%
a = 10
b = 30.0
a + b
# Out:
# 40.0

# %%
print(1 < 10)
print("Linux" == "Windows")
print(1 != "1")
# Out:
# True
# False
# True

# %%
def greeting(name):
  return 'hello, ' + name

# %%
print(greeting('bangkit'))
# Out:
# hello, bangkit

# %%
hour = 5
if hour < 12:
  print("Good morning!")
def check(number):
  if number > 0:
    return "Positive"
  elif number == 0:
    return "Zero"
  else:
    return "Negative"
print(check(2))
# Out:
# Good morning!
# Positive

# %%
x = 7 # Initialisation of variable
while x > 0:
  print("positive x = " + str(x))
  x = x - 1
print("now x = " + str(x))
# Out:
# positive x = 7
# positive x = 6
# positive x = 5
# positive x = 4
# positive x = 3
# positive x = 2
# positive x = 1
# now x = 0

# %%
for x in range(3): # 0, 1, 2
  print("x = " + str(x))
# Out:
# x = 0
# x = 1
# x = 2

# %%
for x in range(3):
  print("x = " + str(x))
  if x == 1:
    break; # quit from loop
# Out:
# x = 0
# x = 1

# %%
for x in range(3, 0, -1):
  if x % 2 == 0:
    continue # skip even
  print(x)
# Out:
# 3
# 1

# %%
length = 10
width = 2
area = length * width

# %%
x = 10
y = 2
a = x * y

# %%
x = 0
while x < 10:
  print("x = " + str(x))
  x = x - 1
print ("now x = " + str(x))
# Out:
# Streaming output truncated to the last 5000 lines.
# x = -38046
# x = -38047
# x = -38048
# x = -38049
# x = -38050
# x = -38051
# x = -38052
# x = -38053
# x = -38054
# x = -38055
# x = -38056
# x = -38057
# x = -38058
# x = -38059
# x = -38060
# x = -38061
# x = -38062
# x = -38063
# x = -38064
# x = -38065
# x = -38066
# x = -38067
# x = -38068
# x = -38069
# x = -38070
# x = -38071
# x = -38072
# x = -38073
# x = -38074
# x = -38075
# x = -38076
# x = -38077
# x = -38078
# x = -38079
# x = -38080
# x = -38081
# x = -38082
# x = -38083
# x = -38084
# x = -38085
# x = -38086
# x = -38087
# x = -38088
# x = -38089
# x = -38090
# x = -38091
# x = -38092
# x = -38093
# x = -38094
# x = -38095
# x = -38096
# x = -38097
# x = -38098
# x = -38099
# x = -38100
# x = -38101
# x = -38102
# x = -38103
# x = -38104
# x = -38105
# x = -38106
# x = -38107
# x = -38108
# x = -38109
# x = -38110
# x = -38111
# x = -38112
# x = -38113
# x = -38114
# x = -38115
# x = -38116
# x = -38117
# ...

# %%
paths = ['ML', 'Cloud']
print(paths[0])
# Out:
# ML

# %%
paths.append('Android')

# %%
paths.remove('Cloud')

# %%
paths.insert(1, 'Mobile')

# %%
paths.pop(-1) # remove 'Android'
# Out:
# 'Android'

# %%
print(paths)
# Out:
# ['ML', 'Mobile']

# %%
paths2 = ('ML', 'Cloud')
print(paths2[0])
# Out:
# ML

# %%
paths2[1] = 'Machine Learning'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-d1b6762a68a9> in <cell line: 1>()
# ----> 1 paths2[1] = 'Machine Learning'
#
# TypeError: 'tuple' object does not support item assignment

# %%
students = {
    'ml': 500,
    'mobile': 700,
    'cloud': 900
}
print(students['cloud']) # 900
# Out:
# 900

# %%
students['ml'] = 1000
print(students['ml'])
# Out:
# 1000
